# %%
import pandas as pd
import numpy as np

casas = pd.read_csv("houses_sp.csv", sep=",")

casas
# Out:
#            city   area  rooms  bathroom  parking spaces floor   hoa   rent  \
# 0     São Paulo   70.0    2.0         1             1.0     7  2065   3300
# 1     São Paulo  320.0    4.0         4             2.0    20  1200   4960
# 2     São Paulo   25.0    1.0         1             NaN     1     0    800
# 3     São Paulo  650.0    3.0         3             7.0     -     0   8000
# 4     São Paulo  213.0    NaN         4             4.0     4  2254   3223
# ...         ...    ...    ...       ...             ...   ...   ...    ...
# 7138  São Paulo   24.0    2.0         2             1.0    13   993   5500
# 7139  São Paulo  280.0    4.0         4             2.0     5  4200   4000
# 7140  São Paulo   83.0    3.0         2             2.0    11   888   7521
# 7141  São Paulo  150.0    3.0         3             2.0     8     0  13500
# 7142  São Paulo  285.0    4.0         4             4.0    17  3100  15000
#
# ...
